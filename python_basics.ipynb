# %%
ema_period=20
trade_count=0

# %%
eth_price=2139.80
risk_price_trade=0.02

# %%
symbol="ETH/USDT"
direction="long"

# %%
is_trending=True
has_stop_loss=False

# %%
account_balance=500.0
risk_per_trade=0.02
max_loss=account_balance*risk_per_trade
print(f"单笔最大亏损：{max_loss}USD")
# Out:
# 单笔最大亏损：10.0USD

# %%
change=-80
status="上涨"if change > 0 else "下跌"
print(f"{symbol}今日{status}{abs(change):.2f}%")
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 change=-80
#       2 status="上涨"if change > 0 else "下跌"
# ----> 3 print(f"{symbol}今日{status}{abs(change):.2f}%")
#
# NameError: name 'symbol' is not defined
